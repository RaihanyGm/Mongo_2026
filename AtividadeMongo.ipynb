# %%
from pymongo import MongoClient
import pandas as pd
from datetime import datetime

# %%
client = MongoClient("mongodb://root:rootpass@localhost:27017")
print (client.server_info()['version'])
# Out:
# 8.2.6

# %%
db = client['veterinaria']
colecao = db['atendimento']

# %%
dados = [
{"tutor":"Ana","animal":"Cachorro","nome_pet":"Rex1","servico":"Consulta","valor":120,"cidade":"Assis","data":datetime(2026,3,1),"forma_pagamento":"Pix"},
{"tutor":"Bruno","animal":"Gato","nome_pet":"Mimi2","servico":"Vacinação","valor":95,"cidade":"Assis","data":datetime(2026,3,2),"forma_pagamento":"Cartão"},
{"tutor":"Carlos","animal":"Cachorro","nome_pet":"Thor3","servico":"Banho","valor":60,"cidade":"Assis","data":datetime(2026,3,3),"forma_pagamento":"Dinheiro"},
{"tutor":"Daniela","animal":"Ave","nome_pet":"Piu4","servico":"Exame","valor":180,"cidade":"Assis","data":datetime(2026,3,4),"forma_pagamento":"Cartão"},
{"tutor":"Eduardo","animal":"Gato","nome_pet":"Luna5","servico":"Consulta","valor":130,"cidade":"Assis","data":datetime(2026,3,5),"forma_pagamento":"Pix"},
{"tutor":"Fernanda","animal":"Cachorro","nome_pet":"Bob6","servico":"Vacinação","valor":90,"cidade":"Assis","data":datetime(2026,3,6),"forma_pagamento":"Dinheiro"},
{"tutor":"Gabriel","animal":"Coelho","nome_pet":"Pompom7","servico":"Consulta","valor":110,"cidade":"Assis","data":datetime(2026,3,7),"forma_pagamento":"Pix"},
{"tutor":"Helena","animal":"Cachorro","nome_pet":"Mel8","servico":"Cirurgia","valor":820,"cidade":"Assis","data":datetime(2026,3,8),"forma_pagamento":"Cartão"},
{"tutor":"Igor","animal":"Gato","nome_pet":"Simba9","servico":"Banho","valor":55,"cidade":"Assis","data":datetime(2026,3,9),"forma_pagamento":"Cartão"},
{"tutor":"Juliana","animal":"Cachorro","nome_pet":"Nina10","servico":"Consulta","valor":125,"cidade":"Assis","data":datetime(2026,3,10),"forma_pagamento":"Pix"},
{"tutor":"Lucas","animal":"Ave","nome_pet":"Sky11","servico":"Exame","valor":200,"cidade":"Assis","data":datetime(2026,3,11),"forma_pagamento":"Cartão"},
{"tutor":"Mariana","animal":"Gato","nome_pet":"Lili12","servico":"Consulta","valor":135,"cidade":"Assis","data":datetime(2026,3,12),"forma_pagamento":"Pix"},
{"tutor":"Nicolas","animal":"Cachorro","nome_pet":"Bolt13","servico":"Vacinação","valor":100,"cidade":"Assis","data":datetime(2026,3,13),"forma_pagamento":"Dinheiro"},
{"tutor":"Patricia","animal":"Cachorro","nome_pet":"Max14","servico":"Consulta","valor":140,"cidade":"Ourinhos","data":datetime(2026,3,1),"forma_pagamento":"Pix"},
{"tutor":"Rafael","animal":"Gato","nome_pet":"Mia15","servico":"Banho","valor":65,"cidade":"Ourinhos","data":datetime(2026,3,2),"forma_pagamento":"Cartão"},
{"tutor":"Sofia","animal":"Cachorro","nome_pet":"Luna16","servico":"Cirurgia","valor":900,"cidade":"Ourinhos","data":datetime(2026,3,3),"forma_pagamento":"Cartão"},
{"tutor":"Thiago","animal":"Ave","nome_pet":"Blue17","servico":"Exame","valor":170,"cidade":"Ourinhos","data":datetime(2026,3,4),"forma_pagamento":"Pix"},
{"tutor":"Vanessa","animal":"Gato","nome_pet":"Nino18","servico":"Consulta","valor":125,"cidade":"Ourinhos","data":datetime(2026,3,5),"forma_pagamento":"Dinheiro"},
{"tutor":"William","animal":"Cachorro","nome_pet":"Thor19","servico":"Vacinação","valor":95,"cidade":"Ourinhos","data":datetime(2026,3,6),"forma_pagamento":"Pix"},
{"tutor":"Beatriz","animal":"Coelho","nome_pet":"Fluffy20","servico":"Consulta","valor":115,"cidade":"Ourinhos","data":datetime(2026,3,7),"forma_pagamento":"Cartão"},
{"tutor":"Caio","animal":"Cachorro","nome_pet":"Spike21","servico":"Banho","valor":70,"cidade":"Ourinhos","data":datetime(2026,3,8),"forma_pagamento":"Dinheiro"},
{"tutor":"Diego","animal":"Gato","nome_pet":"Tom22","servico":"Consulta","valor":135,"cidade":"Ourinhos","data":datetime(2026,3,9),"forma_pagamento":"Pix"},
{"tutor":"Elisa","animal":"Cachorro","nome_pet":"Mel23","servico":"Exame","valor":210,"cidade":"Ourinhos","data":datetime(2026,3,10),"forma_pagamento":"Cartão"},
{"tutor":"Felipe","animal":"Ave","nome_pet":"Kiwi24","servico":"Consulta","valor":120,"cidade":"Ourinhos","data":datetime(2026,3,11),"forma_pagamento":"Pix"},
{"tutor":"Gisele","animal":"Gato","nome_pet":"Nina25","servico":"Vacinação","valor":85,"cidade":"Ourinhos","data":datetime(2026,3,12),"forma_pagamento":"Dinheiro"},
{"tutor":"Hugo","animal":"Cachorro","nome_pet":"Rex26","servico":"Consulta","valor":150,"cidade":"Ourinhos","data":datetime(2026,3,13),"forma_pagamento":"Cartão"},
{"tutor":"Iris","animal":"Cachorro","nome_pet":"Bob27","servico":"Consulta","valor":110,"cidade":"Pompeia","data":datetime(2026,3,1),"forma_pagamento":"Pix"},
{"tutor":"Joao","animal":"Gato","nome_pet":"Luna28","servico":"Banho","valor":60,"cidade":"Pompeia","data":datetime(2026,3,2),"forma_pagamento":"Dinheiro"},
{"tutor":"Karen","animal":"Cachorro","nome_pet":"Thor29","servico":"Cirurgia","valor":780,"cidade":"Pompeia","data":datetime(2026,3,3),"forma_pagamento":"Cartão"},
{"tutor":"Leo","animal":"Ave","nome_pet":"Sky30","servico":"Exame","valor":160,"cidade":"Pompeia","data":datetime(2026,3,4),"forma_pagamento":"Pix"},
{"tutor":"Marta","animal":"Gato","nome_pet":"Mimi31","servico":"Consulta","valor":120,"cidade":"Pompeia","data":datetime(2026,3,5),"forma_pagamento":"Cartão"},
{"tutor":"Nelson","animal":"Cachorro","nome_pet":"Max32","servico":"Vacinação","valor":90,"cidade":"Pompeia","data":datetime(2026,3,6),"forma_pagamento":"Pix"},
{"tutor":"Olga","animal":"Coelho","nome_pet":"Pompom33","servico":"Consulta","valor":105,"cidade":"Pompeia","data":datetime(2026,3,7),"forma_pagamento":"Dinheiro"},
{"tutor":"Paulo","animal":"Cachorro","nome_pet":"Bolt34","servico":"Banho","valor":75,"cidade":"Pompeia","data":datetime(2026,3,8),"forma_pagamento":"Cartão"},
{"tutor":"Quezia","animal":"Gato","nome_pet":"Simba35","servico":"Consulta","valor":130,"cidade":"Pompeia","data":datetime(2026,3,9),"forma_pagamento":"Pix"},
{"tutor":"Renato","animal":"Cachorro","nome_pet":"Nina36","servico":"Exame","valor":190,"cidade":"Pompeia","data":datetime(2026,3,10),"forma_pagamento":"Cartão"},
{"tutor":"Sara","animal":"Ave","nome_pet":"Blue37","servico":"Consulta","valor":115,"cidade":"Pompeia","data":datetime(2026,3,11),"forma_pagamento":"Pix"},
{"tutor":"Tiago","animal":"Gato","nome_pet":"Lili38","servico":"Vacinação","valor":85,"cidade":"Pompeia","data":datetime(2026,3,12),"forma_pagamento":"Dinheiro"},
{"tutor":"Ursula","animal":"Cachorro","nome_pet":"Rex39","servico":"Consulta","valor":145,"cidade":"Marilia","data":datetime(2026,3,1),"forma_pagamento":"Pix"},
{"tutor":"Vitor","animal":"Gato","nome_pet":"Mia40","servico":"Banho","valor":70,"cidade":"Marilia","data":datetime(2026,3,2),"forma_pagamento":"Cartão"},
{"tutor":"Wesley","animal":"Cachorro","nome_pet":"Thor41","servico":"Cirurgia","valor":870,"cidade":"Marilia","data":datetime(2026,3,3),"forma_pagamento":"Cartão"},
{"tutor":"Xuxa","animal":"Ave","nome_pet":"Piu42","servico":"Exame","valor":175,"cidade":"Marilia","data":datetime(2026,3,4),"forma_pagamento":"Pix"},
{"tutor":"Yara","animal":"Gato","nome_pet":"Luna43","servico":"Consulta","valor":135,"cidade":"Marilia","data":datetime(2026,3,5),"forma_pagamento":"Dinheiro"},
{"tutor":"Zeca","animal":"Cachorro","nome_pet":"Bob44","servico":"Vacinação","valor":100,"cidade":"Marilia","data":datetime(2026,3,6),"forma_pagamento":"Pix"},
{"tutor":"Aline","animal":"Coelho","nome_pet":"Fluffy45","servico":"Consulta","valor":120,"cidade":"Marilia","data":datetime(2026,3,7),"forma_pagamento":"Cartão"},
{"tutor":"Bruna","animal":"Cachorro","nome_pet":"Spike46","servico":"Banho","valor":80,"cidade":"Marilia","data":datetime(2026,3,8),"forma_pagamento":"Dinheiro"},
{"tutor":"Cesar","animal":"Gato","nome_pet":"Tom47","servico":"Consulta","valor":140,"cidade":"Marilia","data":datetime(2026,3,9),"forma_pagamento":"Pix"},
{"tutor":"Dora","animal":"Cachorro","nome_pet":"Mel48","servico":"Exame","valor":220,"cidade":"Marilia","data":datetime(2026,3,10),"forma_pagamento":"Cartão"},
{"tutor":"Enzo","animal":"Ave","nome_pet":"Kiwi49","servico":"Consulta","valor":130,"cidade":"Marilia","data":datetime(2026,3,11),"forma_pagamento":"Pix"},
{"tutor":"Fabio","animal":"Gato","nome_pet":"Nina50","servico":"Vacinação","valor":90,"cidade":"Marilia","data":datetime(2026,3,12),"forma_pagamento":"Dinheiro"},
]

# %%
colecao.insert_many(dados)
# Out:
# InsertManyResult([ObjectId('69c33a494e646ee4c17ce501'), ObjectId('69c33a494e646ee4c17ce502'), ObjectId('69c33a494e646ee4c17ce503'), ObjectId('69c33a494e646ee4c17ce504'), ObjectId('69c33a494e646ee4c17ce505'), ObjectId('69c33a494e646ee4c17ce506'), ObjectId('69c33a494e646ee4c17ce507'), ObjectId('69c33a494e646ee4c17ce508'), ObjectId('69c33a494e646ee4c17ce509'), ObjectId('69c33a494e646ee4c17ce50a'), ObjectId('69c33a494e646ee4c17ce50b'), ObjectId('69c33a494e646ee4c17ce50c'), ObjectId('69c33a494e646ee4c17ce50d'), ObjectId('69c33a494e646ee4c17ce50e'), ObjectId('69c33a494e646ee4c17ce50f'), ObjectId('69c33a494e646ee4c17ce510'), ObjectId('69c33a494e646ee4c17ce511'), ObjectId('69c33a494e646ee4c17ce512'), ObjectId('69c33a494e646ee4c17ce513'), ObjectId('69c33a494e646ee4c17ce514'), ObjectId('69c33a494e646ee4c17ce515'), ObjectId('69c33a494e646ee4c17ce516'), ObjectId('69c33a494e646ee4c17ce517'), ObjectId('69c33a494e646ee4c17ce518'), ObjectId('69c33a494e646ee4c17ce519'), ObjectId('69c33a494e646ee4c17ce51a'), ObjectId('69c33a494e646ee4c17ce51b'), ObjectId('69c33a494e646ee4c17ce51c'), ObjectId('69c33a494e646ee4c17ce51d'), ObjectId('69c33a494e646ee4c17ce51e'), ObjectId('69c33a494e646ee4c17ce51f'), ObjectId('69c33a494e646ee4c17ce520'), ObjectId('69c33a494e646ee4c17ce521'), ObjectId('69c33a494e646ee4c17ce522'), ObjectId('69c33a494e646ee4c17ce523'), ObjectId('69c33a494e646ee4c17ce524'), ObjectId('69c33a494e646ee4c17ce525'), ObjectId('69c33a494e646ee4c17ce526'), ObjectId('69c33a494e646ee4c17ce527'), ObjectId('69c33a494e646ee4c17ce528'), ObjectId('69c33a494e646ee4c17ce529'), ObjectId('69c33a494e646ee4c17ce52a'), ObjectId('69c33a494e646ee4c17ce52b'), ObjectId('69c33a494e646ee4c17ce52c'), ObjectId('69c33a494e646ee4c17ce52d'), ObjectId('69c33a494e646ee4c17ce52e'), ObjectId('69c33a494e646ee4c17ce52f'), ObjectId('69c33a494e646ee4c17ce530'), ObjectId('69c33a494e646ee4c17ce531'), ObjectId('69c33a494e646ee4c17ce532')], acknowledged=True)

# %%
preco = list(colecao.find({
    'valor' : {'$gte' : 90, '$lte' : 200}
}))

display(preco)
# Out:
# [{'_id': ObjectId('69c33a494e646ee4c17ce501'),
#   'tutor': 'Ana',
#   'animal': 'Cachorro',
#   'nome_pet': 'Rex1',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce502'),
#   'tutor': 'Bruno',
#   'animal': 'Gato',
#   'nome_pet': 'Mimi2',
#   'servico': 'Vacinação',
#   'valor': 95,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce504'),
#   'tutor': 'Daniela',
#   'animal': 'Ave',
#   'nome_pet': 'Piu4',
#   'servico': 'Exame',
#   'valor': 180,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce505'),
#   'tutor': 'Eduardo',
#   'animal': 'Gato',
#   'nome_pet': 'Luna5',
#   'servico': 'Consulta',
#   'valor': 130,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce506'),
#   'tutor': 'Fernanda',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bob6',
#   'servico': 'Vacinação',
#   'valor': 90,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce507'),
#   'tutor': 'Gabriel',
#   'animal': 'Coelho',
#   'nome_pet': 'Pompom7',
#   'servico': 'Consulta',
#   'valor': 110,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce50a'),
#   'tutor': 'Juliana',
#   'animal': 'Cachorro',
#   'nome_pet': 'Nina10',
#   'servico': 'Consulta',
#   'valor': 125,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 10, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce50b'),
#   'tutor': 'Lucas',
#   'animal': 'Ave',
#   'nome_pet': 'Sky11',
#   'servico': 'Exame',
#   'valor': 200,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce50c'),
#   'tutor': 'Mariana',
#   'animal': 'Gato',
#   'nome_pet': 'Lili12',
#   'servico': 'Consulta',
#   'valor': 135,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 12, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce50d'),
#   'tutor': 'Nicolas',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bolt13',
#   'servico': 'Vacinação',
#   'valor': 100,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 13, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce50e'),
#   'tutor': 'Patricia',
#   'animal': 'Cachorro',
#   'nome_pet': 'Max14',
#   'servico': 'Consulta',
#   'valor': 140,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce511'),
#   'tutor': 'Thiago',
#   'animal': 'Ave',
#   'nome_pet': 'Blue17',
#   'servico': 'Exame',
#   'valor': 170,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce512'),
#   'tutor': 'Vanessa',
#   'animal': 'Gato',
#   'nome_pet': 'Nino18',
#   'servico': 'Consulta',
#   'valor': 125,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce513'),
#   'tutor': 'William',
#   'animal': 'Cachorro',
#   'nome_pet': 'Thor19',
#   'servico': 'Vacinação',
#   'valor': 95,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce514'),
#   'tutor': 'Beatriz',
#   'animal': 'Coelho',
#   'nome_pet': 'Fluffy20',
#   'servico': 'Consulta',
#   'valor': 115,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce516'),
#   'tutor': 'Diego',
#   'animal': 'Gato',
#   'nome_pet': 'Tom22',
#   'servico': 'Consulta',
#   'valor': 135,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 9, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce518'),
#   'tutor': 'Felipe',
#   'animal': 'Ave',
#   'nome_pet': 'Kiwi24',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce51a'),
#   'tutor': 'Hugo',
#   'animal': 'Cachorro',
#   'nome_pet': 'Rex26',
#   'servico': 'Consulta',
#   'valor': 150,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 13, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce51b'),
#   'tutor': 'Iris',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bob27',
#   'servico': 'Consulta',
#   'valor': 110,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce51e'),
#   'tutor': 'Leo',
#   'animal': 'Ave',
#   'nome_pet': 'Sky30',
#   'servico': 'Exame',
#   'valor': 160,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce51f'),
#   'tutor': 'Marta',
#   'animal': 'Gato',
#   'nome_pet': 'Mimi31',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce520'),
#   'tutor': 'Nelson',
#   'animal': 'Cachorro',
#   'nome_pet': 'Max32',
#   'servico': 'Vacinação',
#   'valor': 90,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce521'),
#   'tutor': 'Olga',
#   'animal': 'Coelho',
#   'nome_pet': 'Pompom33',
#   'servico': 'Consulta',
#   'valor': 105,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce523'),
#   'tutor': 'Quezia',
#   'animal': 'Gato',
#   'nome_pet': 'Simba35',
#   'servico': 'Consulta',
#   'valor': 130,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 9, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce524'),
#   'tutor': 'Renato',
#   'animal': 'Cachorro',
#   'nome_pet': 'Nina36',
#   'servico': 'Exame',
#   'valor': 190,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 10, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce525'),
#   'tutor': 'Sara',
#   'animal': 'Ave',
#   'nome_pet': 'Blue37',
#   'servico': 'Consulta',
#   'valor': 115,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce527'),
#   'tutor': 'Ursula',
#   'animal': 'Cachorro',
#   'nome_pet': 'Rex39',
#   'servico': 'Consulta',
#   'valor': 145,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce52a'),
#   'tutor': 'Xuxa',
#   'animal': 'Ave',
#   'nome_pet': 'Piu42',
#   'servico': 'Exame',
#   'valor': 175,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce52b'),
#   'tutor': 'Yara',
#   'animal': 'Gato',
#   'nome_pet': 'Luna43',
#   'servico': 'Consulta',
#   'valor': 135,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce52c'),
#   'tutor': 'Zeca',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bob44',
#   'servico': 'Vacinação',
#   'valor': 100,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce52d'),
#   'tutor': 'Aline',
#   'animal': 'Coelho',
#   'nome_pet': 'Fluffy45',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce52f'),
#   'tutor': 'Cesar',
#   'animal': 'Gato',
#   'nome_pet': 'Tom47',
#   'servico': 'Consulta',
#   'valor': 140,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 9, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce531'),
#   'tutor': 'Enzo',
#   'animal': 'Ave',
#   'nome_pet': 'Kiwi49',
#   'servico': 'Consulta',
#   'valor': 130,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce532'),
#   'tutor': 'Fabio',
#   'animal': 'Gato',
#   'nome_pet': 'Nina50',
#   'servico': 'Vacinação',
#   'valor': 90,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 12, 0, 0),
#   'forma_pagamento': 'Dinheiro'}]

# %%
cidade = list(colecao.find({
    'cidade' : {'$in' : ['Assis', 'Ourinho','Pompeia', 'Ourinhos', 'Marilia']}
}))
display(cidade)
# Out:
# [{'_id': ObjectId('69c33a494e646ee4c17ce501'),
#   'tutor': 'Ana',
#   'animal': 'Cachorro',
#   'nome_pet': 'Rex1',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce502'),
#   'tutor': 'Bruno',
#   'animal': 'Gato',
#   'nome_pet': 'Mimi2',
#   'servico': 'Vacinação',
#   'valor': 95,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce503'),
#   'tutor': 'Carlos',
#   'animal': 'Cachorro',
#   'nome_pet': 'Thor3',
#   'servico': 'Banho',
#   'valor': 60,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 3, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce504'),
#   'tutor': 'Daniela',
#   'animal': 'Ave',
#   'nome_pet': 'Piu4',
#   'servico': 'Exame',
#   'valor': 180,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce505'),
#   'tutor': 'Eduardo',
#   'animal': 'Gato',
#   'nome_pet': 'Luna5',
#   'servico': 'Consulta',
#   'valor': 130,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce506'),
#   'tutor': 'Fernanda',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bob6',
#   'servico': 'Vacinação',
#   'valor': 90,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce507'),
#   'tutor': 'Gabriel',
#   'animal': 'Coelho',
#   'nome_pet': 'Pompom7',
#   'servico': 'Consulta',
#   'valor': 110,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce508'),
#   'tutor': 'Helena',
#   'animal': 'Cachorro',
#   'nome_pet': 'Mel8',
#   'servico': 'Cirurgia',
#   'valor': 820,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 8, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce509'),
#   'tutor': 'Igor',
#   'animal': 'Gato',
#   'nome_pet': 'Simba9',
#   'servico': 'Banho',
#   'valor': 55,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 9, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce50a'),
#   'tutor': 'Juliana',
#   'animal': 'Cachorro',
#   'nome_pet': 'Nina10',
#   'servico': 'Consulta',
#   'valor': 125,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 10, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce50b'),
#   'tutor': 'Lucas',
#   'animal': 'Ave',
#   'nome_pet': 'Sky11',
#   'servico': 'Exame',
#   'valor': 200,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce50c'),
#   'tutor': 'Mariana',
#   'animal': 'Gato',
#   'nome_pet': 'Lili12',
#   'servico': 'Consulta',
#   'valor': 135,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 12, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce50d'),
#   'tutor': 'Nicolas',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bolt13',
#   'servico': 'Vacinação',
#   'valor': 100,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 13, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce50e'),
#   'tutor': 'Patricia',
#   'animal': 'Cachorro',
#   'nome_pet': 'Max14',
#   'servico': 'Consulta',
#   'valor': 140,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce50f'),
#   'tutor': 'Rafael',
#   'animal': 'Gato',
#   'nome_pet': 'Mia15',
#   'servico': 'Banho',
#   'valor': 65,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce510'),
#   'tutor': 'Sofia',
#   'animal': 'Cachorro',
#   'nome_pet': 'Luna16',
#   'servico': 'Cirurgia',
#   'valor': 900,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 3, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce511'),
#   'tutor': 'Thiago',
#   'animal': 'Ave',
#   'nome_pet': 'Blue17',
#   'servico': 'Exame',
#   'valor': 170,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce512'),
#   'tutor': 'Vanessa',
#   'animal': 'Gato',
#   'nome_pet': 'Nino18',
#   'servico': 'Consulta',
#   'valor': 125,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce513'),
#   'tutor': 'William',
#   'animal': 'Cachorro',
#   'nome_pet': 'Thor19',
#   'servico': 'Vacinação',
#   'valor': 95,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce514'),
#   'tutor': 'Beatriz',
#   'animal': 'Coelho',
#   'nome_pet': 'Fluffy20',
#   'servico': 'Consulta',
#   'valor': 115,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce515'),
#   'tutor': 'Caio',
#   'animal': 'Cachorro',
#   'nome_pet': 'Spike21',
#   'servico': 'Banho',
#   'valor': 70,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 8, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce516'),
#   'tutor': 'Diego',
#   'animal': 'Gato',
#   'nome_pet': 'Tom22',
#   'servico': 'Consulta',
#   'valor': 135,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 9, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce517'),
#   'tutor': 'Elisa',
#   'animal': 'Cachorro',
#   'nome_pet': 'Mel23',
#   'servico': 'Exame',
#   'valor': 210,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 10, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce518'),
#   'tutor': 'Felipe',
#   'animal': 'Ave',
#   'nome_pet': 'Kiwi24',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce519'),
#   'tutor': 'Gisele',
#   'animal': 'Gato',
#   'nome_pet': 'Nina25',
#   'servico': 'Vacinação',
#   'valor': 85,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 12, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce51a'),
#   'tutor': 'Hugo',
#   'animal': 'Cachorro',
#   'nome_pet': 'Rex26',
#   'servico': 'Consulta',
#   'valor': 150,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 13, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce51b'),
#   'tutor': 'Iris',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bob27',
#   'servico': 'Consulta',
#   'valor': 110,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce51c'),
#   'tutor': 'Joao',
#   'animal': 'Gato',
#   'nome_pet': 'Luna28',
#   'servico': 'Banho',
#   'valor': 60,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce51d'),
#   'tutor': 'Karen',
#   'animal': 'Cachorro',
#   'nome_pet': 'Thor29',
#   'servico': 'Cirurgia',
#   'valor': 780,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 3, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce51e'),
#   'tutor': 'Leo',
#   'animal': 'Ave',
#   'nome_pet': 'Sky30',
#   'servico': 'Exame',
#   'valor': 160,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce51f'),
#   'tutor': 'Marta',
#   'animal': 'Gato',
#   'nome_pet': 'Mimi31',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce520'),
#   'tutor': 'Nelson',
#   'animal': 'Cachorro',
#   'nome_pet': 'Max32',
#   'servico': 'Vacinação',
#   'valor': 90,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce521'),
#   'tutor': 'Olga',
#   'animal': 'Coelho',
#   'nome_pet': 'Pompom33',
#   'servico': 'Consulta',
#   'valor': 105,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce522'),
#   'tutor': 'Paulo',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bolt34',
#   'servico': 'Banho',
#   'valor': 75,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 8, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce523'),
#   'tutor': 'Quezia',
#   'animal': 'Gato',
#   'nome_pet': 'Simba35',
#   'servico': 'Consulta',
#   'valor': 130,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 9, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce524'),
#   'tutor': 'Renato',
#   'animal': 'Cachorro',
#   'nome_pet': 'Nina36',
#   'servico': 'Exame',
#   'valor': 190,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 10, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce525'),
#   'tutor': 'Sara',
#   'animal': 'Ave',
#   'nome_pet': 'Blue37',
#   'servico': 'Consulta',
#   'valor': 115,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce526'),
#   'tutor': 'Tiago',
#   'animal': 'Gato',
#   'nome_pet': 'Lili38',
#   'servico': 'Vacinação',
#   'valor': 85,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 12, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce527'),
#   'tutor': 'Ursula',
#   'animal': 'Cachorro',
#   'nome_pet': 'Rex39',
#   'servico': 'Consulta',
#   'valor': 145,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce528'),
#   'tutor': 'Vitor',
#   'animal': 'Gato',
#   'nome_pet': 'Mia40',
#   'servico': 'Banho',
#   'valor': 70,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce529'),
#   'tutor': 'Wesley',
#   'animal': 'Cachorro',
#   'nome_pet': 'Thor41',
#   'servico': 'Cirurgia',
#   'valor': 870,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 3, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce52a'),
#   'tutor': 'Xuxa',
#   'animal': 'Ave',
#   'nome_pet': 'Piu42',
#   'servico': 'Exame',
#   'valor': 175,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce52b'),
#   'tutor': 'Yara',
#   'animal': 'Gato',
#   'nome_pet': 'Luna43',
#   'servico': 'Consulta',
#   'valor': 135,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce52c'),
#   'tutor': 'Zeca',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bob44',
#   'servico': 'Vacinação',
#   'valor': 100,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce52d'),
#   'tutor': 'Aline',
#   'animal': 'Coelho',
#   'nome_pet': 'Fluffy45',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce52e'),
#   'tutor': 'Bruna',
#   'animal': 'Cachorro',
#   'nome_pet': 'Spike46',
#   'servico': 'Banho',
#   'valor': 80,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 8, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce52f'),
#   'tutor': 'Cesar',
#   'animal': 'Gato',
#   'nome_pet': 'Tom47',
#   'servico': 'Consulta',
#   'valor': 140,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 9, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce530'),
#   'tutor': 'Dora',
#   'animal': 'Cachorro',
#   'nome_pet': 'Mel48',
#   'servico': 'Exame',
#   'valor': 220,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 10, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce531'),
#   'tutor': 'Enzo',
#   'animal': 'Ave',
#   'nome_pet': 'Kiwi49',
#   'servico': 'Consulta',
#   'valor': 130,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33a494e646ee4c17ce532'),
#   'tutor': 'Fabio',
#   'animal': 'Gato',
#   'nome_pet': 'Nina50',
#   'servico': 'Vacinação',
#   'valor': 90,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 12, 0, 0),
#   'forma_pagamento': 'Dinheiro'}]

# %%
df = pd.DataFrame(cidade)

# %%
df.isnull().sum()
# Out:
# Series([], dtype: float64)

# %%
ValorTotal = df['valor'].sum()
print("Faturamento Total:",ValorTotal)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 ValorTotal = df['valor'].sum()
#       2 print("Faturamento Total:",ValorTotal)
#
# File /usr/local/python/3.11.15/lib/python3.11/site-packages/pandas/core/frame.py:4378, in DataFrame.__getitem__(self, key)
#    4376 if self.columns.nlevels > 1:
#    4377     return self._getitem_multilevel(key)
# -> 4378 indexer = self.columns.get_loc(key)
#    4379 if is_integer(indexer):
#    4380     indexer = [indexer]
#
# File /usr/local/python/3.11.15/lib/python3.11/site-packages/pandas/core/indexes/range.py:525, in RangeIndex.get_loc(self, key)
#     523         raise KeyError(key) from err
#     524 if isinstance(key, Hashable):
# --> 525     raise KeyError(key)
#     526 self._check_indexing_error(key)
#     527 raise KeyError(key)
#
# KeyError: 'valor'

# %%
faturamentocidade = df['cidade'].value_counts()
faturamentocidade
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 faturamentocidade = df['cidade'].value_counts()
#       2 faturamentocidade
#
# File /usr/local/python/3.11.15/lib/python3.11/site-packages/pandas/core/frame.py:4378, in DataFrame.__getitem__(self, key)
#    4376 if self.columns.nlevels > 1:
#    4377     return self._getitem_multilevel(key)
# -> 4378 indexer = self.columns.get_loc(key)
#    4379 if is_integer(indexer):
#    4380     indexer = [indexer]
#
# File /usr/local/python/3.11.15/lib/python3.11/site-packages/pandas/core/indexes/range.py:525, in RangeIndex.get_loc(self, key)
#     523         raise KeyError(key) from err
#     524 if isinstance(key, Hashable):
# --> 525     raise KeyError(key)
#     526 self._check_indexing_error(key)
#     527 raise KeyError(key)
#
# KeyError: 'cidade'

# %%
faturamentoserviso = df.groupby('serviso')['valor_total'].sum().sort_values(ascending=False)
faturamentoserviso

# %%
media_valorServiso = df['valor_total'].mean()
print(f"Média do valor do Serviso: {media_valorServiso:.2f}")

# %%
cidadeV = df['cidade'].value_counts().idxmax()
cidadeV

# %%
relatorio = {
    'data_geracao' : datetime.now(),
    'faturamento_total': float(faturamento),
    'faturamento_categoria' : faturamento_categoria.to_dict(),
    'produto_top': produto_top,
    'cidade_top' : cidade_top
}

display(relatorio)
