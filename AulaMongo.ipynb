# %%
from pymongo import MongoClient
import pandas as pd
from datetime import datetime

# %%
client = MongoClient("mongodb://root:rootpass@localhost:27017")
print (client.server_info()['version'])
# Out:
# 8.2.6

# %%
db = client['loja']
colecao = db['vendas']

# %%
dados = [
    {
        "cliente": "Ana",
        "produto": "Mouse",
        "categoria": "Informática",
        "quantidade": 2,
        "preco_unitario": 50,
        "cidade": "Ourinhos",
        "data": datetime(2026, 3, 1),
        "forma_pagamento": "Cartão"
    },
    {
        "cliente": "Bruno",
        "produto": "Teclado",
        "categoria": "Informática",
        "quantidade": 1,
        "preco_unitario": 120,
        "cidade": "Jacarezinho",
        "data": datetime(2026, 3, 2),
        "forma_pagamento": "Pix"
    },
    {
        "cliente": "Carla",
        "produto": "Caderno",
        "categoria": "Papelaria",
        "quantidade": 5,
        "preco_unitario": 15,
        "cidade": "Ourinhos",
        "data": datetime(2026, 3, 2),
        "forma_pagamento": "Dinheiro"
    },
    {
        "cliente": "Daniel",
        "produto": "Caneta",
        "categoria": "Papelaria",
        "quantidade": 10,
        "preco_unitario": 3,
        "cidade": "Salto Grande",
        "data": datetime(2026, 3, 3),
        "forma_pagamento": "Pix"
    },
    {
        "cliente": "Elaine",
        "produto": "Monitor",
        "categoria": "Informática",
        "quantidade": 1,
        "preco_unitario": 900,
        "cidade": "Ourinhos",
        "data": datetime(2026, 3, 3),
        "forma_pagamento": "Cartão"
    },
    {
        "cliente": "Fabio",
        "produto": "Mochila",
        "categoria": "Acessórios",
        "quantidade": 2,
        "preco_unitario": 80,
        "cidade": "Jacarezinho",
        "data": datetime(2026, 3, 4),
        "forma_pagamento": "Boleto"
    },
    {
        "cliente": "Gabriela",
        "produto": "Livro",
        "categoria": "Livros",
        "quantidade": 3,
        "preco_unitario": 40,
        "cidade": "Ourinhos",
        "data": datetime(2026, 3, 4),
        "forma_pagamento": "Pix"
    },
    {
        "cliente": "Henrique",
        "produto": "Fone",
        "categoria": "Informática",
        "quantidade": 2,
        "preco_unitario": 150,
        "cidade": "Assis",
        "data": datetime(2026, 3, 5),
        "forma_pagamento": "Cartão"
    },
    {
        "cliente": "Isabela",
        "produto": "Agenda",
        "categoria": "Papelaria",
        "quantidade": 4,
        "preco_unitario": 20,
        "cidade": "Salto Grande",
        "data": datetime(2026, 3, 5),
        "forma_pagamento": "Dinheiro"
    },
    {
        "cliente": "João",
        "produto": "Webcam",
        "categoria": "Informática",
        "quantidade": 1,
        "preco_unitario": 250,
        "cidade": "Ourinhos",
        "data": datetime(2026, 3, 6),
        "forma_pagamento": "Pix"
    }
]

# %%
colecao.insert_many(dados)
# Out:
# InsertManyResult([ObjectId('69c336ca829980a66e6108b8'), ObjectId('69c336ca829980a66e6108b9'), ObjectId('69c336ca829980a66e6108ba'), ObjectId('69c336ca829980a66e6108bb'), ObjectId('69c336ca829980a66e6108bc'), ObjectId('69c336ca829980a66e6108bd'), ObjectId('69c336ca829980a66e6108be'), ObjectId('69c336ca829980a66e6108bf'), ObjectId('69c336ca829980a66e6108c0'), ObjectId('69c336ca829980a66e6108c1')], acknowledged=True)

# %%
dados_exemplo = list(colecao.find({'cliente': 'Bruno'}))
display(dados_exemplo)
# Out:
# [{'_id': ObjectId('69c31af583a9f1cee4be599e'),
#   'cliente': 'Bruno',
#   'produto': 'Teclado',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 120,
#   'cidade': 'Jacarezinho',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c331cb829980a66e6108ad'),
#   'cliente': 'Bruno',
#   'produto': 'Teclado',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 120,
#   'cidade': 'Jacarezinho',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c336ca829980a66e6108b9'),
#   'cliente': 'Bruno',
#   'produto': 'Teclado',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 120,
#   'cidade': 'Jacarezinho',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Pix'}]

# %%
dados_mongo = list(colecao.find({
    'preco_unitario' : {'$gte' : 100, '$lte' : 300}
}))

display(dados_mongo)
# Out:
# [{'_id': ObjectId('69c31af583a9f1cee4be599e'),
#   'cliente': 'Bruno',
#   'produto': 'Teclado',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 120,
#   'cidade': 'Jacarezinho',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c31af583a9f1cee4be59a4'),
#   'cliente': 'Henrique',
#   'produto': 'Fone',
#   'categoria': 'Informática',
#   'quantidade': 2,
#   'preco_unitario': 150,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c31af583a9f1cee4be59a6'),
#   'cliente': 'João',
#   'produto': 'Webcam',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 250,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c331cb829980a66e6108ad'),
#   'cliente': 'Bruno',
#   'produto': 'Teclado',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 120,
#   'cidade': 'Jacarezinho',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c331cb829980a66e6108b3'),
#   'cliente': 'Henrique',
#   'produto': 'Fone',
#   'categoria': 'Informática',
#   'quantidade': 2,
#   'preco_unitario': 150,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c331cb829980a66e6108b5'),
#   'cliente': 'João',
#   'produto': 'Webcam',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 250,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c336ca829980a66e6108b9'),
#   'cliente': 'Bruno',
#   'produto': 'Teclado',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 120,
#   'cidade': 'Jacarezinho',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c336ca829980a66e6108bf'),
#   'cliente': 'Henrique',
#   'produto': 'Fone',
#   'categoria': 'Informática',
#   'quantidade': 2,
#   'preco_unitario': 150,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c336ca829980a66e6108c1'),
#   'cliente': 'João',
#   'produto': 'Webcam',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 250,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'}]

# %%
dados_cidade = list(colecao.find({
    'cidade' : {'$in' : ['Ourinhos', 'Assis']}
}))
display(dados_cidade)
# Out:
# [{'_id': ObjectId('69c31af583a9f1cee4be599d'),
#   'cliente': 'Ana',
#   'produto': 'Mouse',
#   'categoria': 'Informática',
#   'quantidade': 2,
#   'preco_unitario': 50,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c31af583a9f1cee4be599f'),
#   'cliente': 'Carla',
#   'produto': 'Caderno',
#   'categoria': 'Papelaria',
#   'quantidade': 5,
#   'preco_unitario': 15,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c31af583a9f1cee4be59a1'),
#   'cliente': 'Elaine',
#   'produto': 'Monitor',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 900,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 3, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c31af583a9f1cee4be59a3'),
#   'cliente': 'Gabriela',
#   'produto': 'Livro',
#   'categoria': 'Livros',
#   'quantidade': 3,
#   'preco_unitario': 40,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c31af583a9f1cee4be59a4'),
#   'cliente': 'Henrique',
#   'produto': 'Fone',
#   'categoria': 'Informática',
#   'quantidade': 2,
#   'preco_unitario': 150,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c31af583a9f1cee4be59a6'),
#   'cliente': 'João',
#   'produto': 'Webcam',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 250,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c331cb829980a66e6108ac'),
#   'cliente': 'Ana',
#   'produto': 'Mouse',
#   'categoria': 'Informática',
#   'quantidade': 2,
#   'preco_unitario': 50,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c331cb829980a66e6108ae'),
#   'cliente': 'Carla',
#   'produto': 'Caderno',
#   'categoria': 'Papelaria',
#   'quantidade': 5,
#   'preco_unitario': 15,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c331cb829980a66e6108b0'),
#   'cliente': 'Elaine',
#   'produto': 'Monitor',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 900,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 3, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c331cb829980a66e6108b2'),
#   'cliente': 'Gabriela',
#   'produto': 'Livro',
#   'categoria': 'Livros',
#   'quantidade': 3,
#   'preco_unitario': 40,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c331cb829980a66e6108b3'),
#   'cliente': 'Henrique',
#   'produto': 'Fone',
#   'categoria': 'Informática',
#   'quantidade': 2,
#   'preco_unitario': 150,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c331cb829980a66e6108b5'),
#   'cliente': 'João',
#   'produto': 'Webcam',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 250,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c336ca829980a66e6108b8'),
#   'cliente': 'Ana',
#   'produto': 'Mouse',
#   'categoria': 'Informática',
#   'quantidade': 2,
#   'preco_unitario': 50,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c336ca829980a66e6108ba'),
#   'cliente': 'Carla',
#   'produto': 'Caderno',
#   'categoria': 'Papelaria',
#   'quantidade': 5,
#   'preco_unitario': 15,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c336ca829980a66e6108bc'),
#   'cliente': 'Elaine',
#   'produto': 'Monitor',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 900,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 3, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c336ca829980a66e6108be'),
#   'cliente': 'Gabriela',
#   'produto': 'Livro',
#   'categoria': 'Livros',
#   'quantidade': 3,
#   'preco_unitario': 40,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c336ca829980a66e6108bf'),
#   'cliente': 'Henrique',
#   'produto': 'Fone',
#   'categoria': 'Informática',
#   'quantidade': 2,
#   'preco_unitario': 150,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c336ca829980a66e6108c1'),
#   'cliente': 'João',
#   'produto': 'Webcam',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 250,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'}]

# %%
df = pd.DataFrame(dados_cidade)

# %%
df.isnull().sum()
# Out:
# _id                0
# cliente            0
# produto            0
# categoria          0
# quantidade         0
# preco_unitario     0
# cidade             0
# data               0
# forma_pagamento    0
# dtype: int64

# %%
df['valor_total'] = df['quantidade'] = df['preco_unitario']
df.head(3)
# Out:
#                         _id cliente  produto    categoria  quantidade  \
# 0  69c31af583a9f1cee4be599d     Ana    Mouse  Informática          50
# 1  69c31af583a9f1cee4be599f   Carla  Caderno    Papelaria          15
# 2  69c31af583a9f1cee4be59a1  Elaine  Monitor  Informática         900
#
#    preco_unitario    cidade       data forma_pagamento  valor_total
# 0              50  Ourinhos 2026-03-01          Cartão           50
# 1              15  Ourinhos 2026-03-02        Dinheiro           15
# 2             900  Ourinhos 2026-03-03          Cartão          900

# %%
faturamento = df['valor_total'].sum()
print("Faturamento Total: ", faturamento)
# Out:
# Faturamento Total:  4215

# %%
faturamento_categoria = df.groupby('categoria')['valor_total'].sum().sort_values(ascending=False)
faturamento_categoria
# Out:
# categoria
# Informática    4050
# Livros          120
# Papelaria        45
# Name: valor_total, dtype: int64

# %%
faturamento_produto = df.groupby('produto')['valor_total'].sum().sort_values(ascending=False)
faturamento_produto
# Out:
# produto
# Monitor    2700
# Webcam      750
# Fone        450
# Mouse       150
# Livro       120
# Caderno      45
# Name: valor_total, dtype: int64

# %%
vendas_por_cidade = df['cidade'].value_counts()
vendas_por_cidade
# Out:
# cidade
# Ourinhos    15
# Assis        3
# Name: count, dtype: int64

# %%
media_valor_vendas = df['valor_total'].mean()
print(f"Média do valor das vendas: {media_valor_vendas:.2f}")
# Out:
# Média do valor das vendas: 234.17

# %%
produto_top = df.groupby('produto')['valor_total'].sum().idxmax()
produto_top
# Out:
# 'Monitor'

# %%
cidade_top = df['cidade'].value_counts().idxmax()
cidade_top
# Out:
# 'Ourinhos'

# %%
relatorio = {
    'data_geracao' : datetime.now(),
    'faturamento_total': float(faturamento),
    'faturamento_categoria' : faturamento_categoria.to_dict(),
    'produto_top': produto_top,
    'cidade_top' : cidade_top
}

display(relatorio)
# Out:
# {'data_geracao': datetime.datetime(2026, 3, 25, 1, 13, 46, 375378),
#  'faturamento_total': 4215.0,
#  'faturamento_categoria': {'Informática': 4050,
#   'Livros': 120,
#   'Papelaria': 45},
#  'produto_top': 'Monitor',
#  'cidade_top': 'Ourinhos'}

# %%
colecao_relatorios = db['relatorios']
colecao_relatorios.insert_one(relatorio)
# Out:
# InsertOneResult(ObjectId('69c336ca829980a66e6108c2'), acknowledged=True)

# %%
for r in colecao_relatorios.find():
    display(r)
# Out:
# {'_id': ObjectId('69c331cb829980a66e6108b6'),
#  'data_geracao': datetime.datetime(2026, 3, 25, 0, 52, 27, 494000),
#  'faturamento_total': 2810.0,
#  'faturamento_categoria': {'Informática': 2700, 'Livros': 80, 'Papelaria': 30},
#  'produto_top': 'Monitor',
#  'cidade_top': 'Ourinhos'}
# {'_id': ObjectId('69c336ca829980a66e6108c2'),
#  'data_geracao': datetime.datetime(2026, 3, 25, 1, 13, 46, 375000),
#  'faturamento_total': 4215.0,
#  'faturamento_categoria': {'Informática': 4050,
#   'Livros': 120,
#   'Papelaria': 45},
#  'produto_top': 'Monitor',
#  'cidade_top': 'Ourinhos'}
